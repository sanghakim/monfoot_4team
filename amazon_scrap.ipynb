# %% [markdown]
# <a href="https://colab.research.google.com/github/sanghakim/project_emba/blob/main/amazon_scrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
# Header to set the requests as a browser requests
headers = {
    'authority': 'www.amazon.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

# %%
# get product id from monfoot store
def getProduct(product_file):
  review_urls = []

  product = pd.read_csv(product_file, sep='\t', header=0, names=['name', 'id'])
  p_names = product['name'].to_list()
  p_ids = product['id'].to_list()

  for name, id in zip(p_names, p_ids):
    url = 'https://www.amazon.com/{0}/product-reviews/{1}'.format(name, id)
    review_urls.append(url)

  return p_names, p_ids, review_urls

# %%
# Extra Data as Html object from amazon Review page
def reviewsHtml(url, len_page):

    # Empty List define to store all pages html data
    soups = []

    # Loop for gather all 3000 reviews from 300 pages via range
    for page_no in range(1, len_page + 1):

        # parameter set as page no to the requests body
        params = {
            'ie': 'UTF8',
            'reviewerType': 'all_reviews',
            'filterByStar': 'critical',
            'pageNumber': page_no,
        }

        # Request make for each page
        response = requests.get(url, headers=headers)

        # Save Html object by using BeautifulSoup4 and lxml parser
        soup = BeautifulSoup(response.text, 'lxml')

        if soup == None:
          print('break in loop')
          break

        # Add single Html page data in master soups list
        soups.append(soup)

    return soups

# %%
# Grab Reviews name, description, date, stars, title from HTML
def getReviews(html_data):

    # Create Empty list to Hold all data
    data_dicts = []

    # Select all Reviews BOX html using css selector
    boxes = html_data.select('div[data-hook="review"]')

    # Iterate all Reviews BOX
    for box in boxes:

        # Select Name using css selector and cleaning text using strip()
        # If Value is empty define value with 'N/A' for all.
        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()
        except Exception as e:
            name = 'N/A'

        try:
            stars = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            stars = 'N/A'

        try:
            title = box.select_one('[data-hook="review-title"]').text.strip()
        except Exception as e:
            title = 'N/A'

        try:
            # Convert date str to dd/mm/yyy format
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[-1]
            date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            date = 'N/A'

        try:
            description = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            description = 'N/A'

        # create Dictionary with al review data
        data_dict = {
            'Name' : name,
            'Stars' : stars,
            'Title' : title,
            'Date' : date,
            'Description' : description
        }

        # Add Dictionary in master empty List
        data_dicts.append(data_dict)

    return data_dicts

# %%
# URL of The amazon Review page
product_file = 'product.csv'
p_names, p_ids, review_urls = getProduct(product_file)
print('#product: {0}'.format(len(review_urls)))
# Out:
# #product: 138

# %%
import time, random

total_reviews = 0
idx = 0

# Grab all HTML
for reviews_url in review_urls:

  print('[review] {0}'.format(reviews_url))

  reviews = []
  len_page = 50
  html_datas = reviewsHtml(reviews_url, len_page)

  # Iterate all Html page
  for html_data in html_datas:

    # Grab review data
    review = getReviews(html_data)

    # add review data in reviews empty list
    reviews += review

  total_reviews += len(reviews)

  # Create a dataframe with reviews Data
  df_reviews = pd.DataFrame(reviews)
  review_file = '{0}_review_of_{1}.csv'.format(idx, p_names[idx])
  df_reviews.to_csv(review_file, encoding='utf8')
  print('please check the fiel, {0}'.format(review_file))
  print('#acc. of reviews: {0}'.format(len(reviews)))

  pause = random.uniform(1,6)
  time.sleep(pause)
  print('get reviews of {0} \n after {1} seconds, we try again'.format(p_names[idx], pause))
  idx += 1

print('Total number of reviews: {0}'.format(total_reviews))
print('Crawling reviews from amazon is completed !!!')
# Out:
# [review] https://www.amazon.com/MONFOOT-5-Pairs-Breathable-No-Show-Non-slip/product-reviews/B0BKRCZQHR
# please check the fiel, 0_review_of_MONFOOT-5-Pairs-Breathable-No-Show-Non-slip.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-5-Pairs-Breathable-No-Show-Non-slip
#  after 3.9107984521586245 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Mountain-Glitter/product-reviews/B0C9Q6FPF8
# please check the fiel, 1_review_of_MONFOOT-Athletic-Cushioned-Mountain-Glitter.csv
# #acc. of reviews: 8
# get reviews of MONFOOT-Athletic-Cushioned-Mountain-Glitter
#  after 3.036039969518602 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CK1QS7T
# please check the fiel, 2_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 1.6484383050749427 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKP7GJQ
# please check the fiel, 3_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 3.885469062709255 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CK46LSX
# please check the fiel, 4_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 3.316777637418361 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKP7GJQ
# please check the fiel, 5_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 2.7635252239276387 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKMVQJV
# please check the fiel, 6_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 3.0283782928425076 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CK1QS7T
# please check the fiel, 7_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 4.7055495010178605 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CK46LSX
# please check the fiel, 8_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 1.9152051544656588 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKP7GJQ
# please check the fiel, 9_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 3.741932919826691 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKMVQJV
# please check the fiel, 10_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 4.239904907597198 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CKKSJC8
# please check the fiel, 11_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 1.1832489978415208 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B09HS711TG
# please check the fiel, 12_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 2.84774378104206 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Cushioned-Running-Performance/product-reviews/B08CK1QS7T
# please check the fiel, 13_review_of_MONFOOT-Athletic-Cushioned-Running-Performance.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Athletic-Cushioned-Running-Performance
#  after 1.9651664894090817 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Running-Cushioned-Performance/product-reviews/B08236GGCD
# please check the fiel, 14_review_of_MONFOOT-Athletic-Running-Cushioned-Performance.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Athletic-Running-Cushioned-Performance
#  after 3.981708529542847 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Running-Cushioned-Quarter/product-reviews/B094CV2H9G
# please check the fiel, 15_review_of_MONFOOT-Athletic-Running-Cushioned-Quarter.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Athletic-Running-Cushioned-Quarter
#  after 1.5351917490649334 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Athletic-Running-Cushioned-Quarter/product-reviews/B094CRTVDT
# please check the fiel, 16_review_of_MONFOOT-Athletic-Running-Cushioned-Quarter.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Athletic-Running-Cushioned-Quarter
#  after 1.2697792351153598 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Comfort-Cushion-Support-Quarter/product-reviews/B092ZG2LT9
# please check the fiel, 17_review_of_MONFOOT-Comfort-Cushion-Support-Quarter.csv
# #acc. of reviews: 90
# get reviews of MONFOOT-Comfort-Cushion-Support-Quarter
#  after 1.6832635532568598 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Comfort-Cushion-Support-Quarter/product-reviews/B092ZG4PZP
# please check the fiel, 18_review_of_MONFOOT-Comfort-Cushion-Support-Quarter.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Comfort-Cushion-Support-Quarter
#  after 3.0684851033971885 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Comfort-Cushion-Support-Quarter/product-reviews/B092ZFSSQM
# please check the fiel, 19_review_of_MONFOOT-Comfort-Cushion-Support-Quarter.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Comfort-Cushion-Support-Quarter
#  after 1.0415328346922221 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Comfort-Cushion-Support-Quarter/product-reviews/B092ZG4PZP
# please check the fiel, 20_review_of_MONFOOT-Comfort-Cushion-Support-Quarter.csv
# #acc. of reviews: 80
# get reviews of MONFOOT-Comfort-Cushion-Support-Quarter
#  after 4.880800113770945 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Comfort-Cushion-Support-Quarter/product-reviews/B092ZFSSQM
# please check the fiel, 21_review_of_MONFOOT-Comfort-Cushion-Support-Quarter.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Comfort-Cushion-Support-Quarter
#  after 5.67543440413598 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Cushion-Comfort-Performance-Quarter/product-reviews/B09X1B31P9
# please check the fiel, 22_review_of_MONFOOT-Cushion-Comfort-Performance-Quarter.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Cushion-Comfort-Performance-Quarter
#  after 3.2932171627511355 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Cushion-Comfort-Performance-Quarter/product-reviews/B09X18HNQ8
# please check the fiel, 23_review_of_MONFOOT-Cushion-Comfort-Performance-Quarter.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Cushion-Comfort-Performance-Quarter
#  after 1.0179224749341307 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Cushion-Comfort-Performance-Quarter/product-reviews/B09X17PXKV
# please check the fiel, 24_review_of_MONFOOT-Cushion-Comfort-Performance-Quarter.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Cushion-Comfort-Performance-Quarter
#  after 2.935962450249339 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Cushion-Comfort-Performance-Quarter/product-reviews/B09X197BH3
# please check the fiel, 25_review_of_MONFOOT-Cushion-Comfort-Performance-Quarter.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Cushion-Comfort-Performance-Quarter
#  after 2.8122656406346964 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CK656BL
# please check the fiel, 26_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 2.396368453339738 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CK656BL
# please check the fiel, 27_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 3.279047066849071 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CKBCJLD
# please check the fiel, 28_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 4.2527891521703935 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CKKVKZZ
# please check the fiel, 29_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 1.935491597213366 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Athletic-Running-Cushioned/product-reviews/B08M64H45L
# please check the fiel, 30_review_of_MONFOOT-Pairs-Athletic-Running-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Pairs-Athletic-Running-Cushioned
#  after 2.269413443315644 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Athletic-Running-Cushioned/product-reviews/B08Q3DB67B
# please check the fiel, 31_review_of_MONFOOT-Pairs-Athletic-Running-Cushioned.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Pairs-Athletic-Running-Cushioned
#  after 5.70165738339865 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Athletic-Running-Cushioned/product-reviews/B08M5P4VXN
# please check the fiel, 32_review_of_MONFOOT-Pairs-Athletic-Running-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Pairs-Athletic-Running-Cushioned
#  after 3.094051335057186 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Athletic-Running-Cushioned/product-reviews/B08M6413HJ
# please check the fiel, 33_review_of_MONFOOT-Pairs-Athletic-Running-Cushioned.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Pairs-Athletic-Running-Cushioned
#  after 2.613311147429452 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Colorful-Topper-Invisible/product-reviews/B08X67XB5R
# please check the fiel, 34_review_of_MONFOOT-Pairs-Colorful-Topper-Invisible.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Pairs-Colorful-Topper-Invisible
#  after 3.1847187532228522 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cotton-Socks-Medium/product-reviews/B08237KV3R
# please check the fiel, 35_review_of_MONFOOT-Pairs-Cotton-Socks-Medium.csv
# #acc. of reviews: 110
# get reviews of MONFOOT-Pairs-Cotton-Socks-Medium
#  after 2.075263390681803 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cotton-Socks-Medium/product-reviews/B08237KV3R
# please check the fiel, 36_review_of_MONFOOT-Pairs-Cotton-Socks-Medium.csv
# #acc. of reviews: 170
# get reviews of MONFOOT-Pairs-Cotton-Socks-Medium
#  after 2.856044386584472 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cotton-Socks-Women/product-reviews/B08234MYC5
# please check the fiel, 37_review_of_MONFOOT-Pairs-Cotton-Socks-Women.csv
# #acc. of reviews: 200
# get reviews of MONFOOT-Pairs-Cotton-Socks-Women
#  after 4.08497111072658 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08JSMNF4T
# please check the fiel, 38_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 240
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 1.8792258450951407 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08JSQJ8Z4
# please check the fiel, 39_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 330
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 1.3684503866119604 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08N64TBK1
# please check the fiel, 40_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 270
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 5.5647530794505755 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08N64C2RQ
# please check the fiel, 41_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 250
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 2.0287391395330507 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08WPD16M7
# please check the fiel, 42_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 240
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 1.1282345138942436 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08WQ488F1
# please check the fiel, 43_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 210
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 5.777302040748995 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08W4XZXNG
# please check the fiel, 44_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 160
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 1.146498485093098 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08W4XFHZ8
# please check the fiel, 45_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 130
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 3.3467226287751664 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Light-Cotton-Socks/product-reviews/B08BL48M2B
# please check the fiel, 46_review_of_MONFOOT-Pairs-Light-Cotton-Socks.csv
# #acc. of reviews: 130
# get reviews of MONFOOT-Pairs-Light-Cotton-Socks
#  after 4.857475228127285 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Light-Cotton-Socks/product-reviews/B08BL3X7DY
# please check the fiel, 47_review_of_MONFOOT-Pairs-Light-Cotton-Socks.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Pairs-Light-Cotton-Socks
#  after 3.57658890607185 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Light-Cotton-Socks/product-reviews/B08BL3X7DY
# please check the fiel, 48_review_of_MONFOOT-Pairs-Light-Cotton-Socks.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Pairs-Light-Cotton-Socks
#  after 2.84974732730929 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Women-Pairs-Moisturizing-Slipper/product-reviews/B09871TFJC
# please check the fiel, 49_review_of_MONFOOT-Women-Pairs-Moisturizing-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Women-Pairs-Moisturizing-Slipper
#  after 4.918214458624613 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Comfortable-Casual/product-reviews/B09X1DGJWN
# please check the fiel, 50_review_of_MONFOOT-Womens-10-Pack-Comfortable-Casual.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-10-Pack-Comfortable-Casual
#  after 4.827412000685931 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Comfortable-Cushion/product-reviews/B09X1CYLCZ
# please check the fiel, 51_review_of_MONFOOT-Womens-10-Pack-Comfortable-Cushion.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-10-Pack-Comfortable-Cushion
#  after 3.723969544236082 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Cotton-Ankle/product-reviews/B08235VNBB
# please check the fiel, 52_review_of_MONFOOT-Womens-10-Pack-Cotton-Ankle.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Womens-10-Pack-Cotton-Ankle
#  after 1.1321276012632544 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Cotton-Ankle/product-reviews/B0823MYD6N
# please check the fiel, 53_review_of_MONFOOT-Womens-10-Pack-Cotton-Ankle.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-10-Pack-Cotton-Ankle
#  after 5.236534654113611 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Cotton-Ankle/product-reviews/B08235VNBB
# please check the fiel, 54_review_of_MONFOOT-Womens-10-Pack-Cotton-Ankle.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-10-Pack-Cotton-Ankle
#  after 3.536760263883602 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-10-Pack-Cotton-Ankle/product-reviews/B0823MYD6N
# please check the fiel, 55_review_of_MONFOOT-Womens-10-Pack-Cotton-Ankle.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-10-Pack-Cotton-Ankle
#  after 3.9384023694648094 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-3-Pack-Vintage-Socks/product-reviews/B09X6Z9ZGJ
# please check the fiel, 56_review_of_MONFOOT-Womens-3-Pack-Vintage-Socks.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-3-Pack-Vintage-Socks
#  after 2.724727133260862 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Ankle-Socks/product-reviews/B09X6ZX5ZJ
# please check the fiel, 57_review_of_MONFOOT-Womens-4-Pack-Ankle-Socks.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Womens-4-Pack-Ankle-Socks
#  after 3.8403248557331873 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Athletic-Cushioned/product-reviews/B09HS4LRGG
# please check the fiel, 58_review_of_MONFOOT-Womens-4-Pack-Athletic-Cushioned.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-4-Pack-Athletic-Cushioned
#  after 3.4072290333132047 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Athletic-Cushioned/product-reviews/B09HS4GPZ7
# please check the fiel, 59_review_of_MONFOOT-Womens-4-Pack-Athletic-Cushioned.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-4-Pack-Athletic-Cushioned
#  after 2.2567809638375738 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Athletic-Cushioned/product-reviews/B09HS4LRGG
# please check the fiel, 60_review_of_MONFOOT-Womens-4-Pack-Athletic-Cushioned.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-4-Pack-Athletic-Cushioned
#  after 1.148404246840822 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Slouch-Extra/product-reviews/B09X6ZWK2S
# please check the fiel, 61_review_of_MONFOOT-Womens-4-Pack-Slouch-Extra.csv
# #acc. of reviews: 80
# get reviews of MONFOOT-Womens-4-Pack-Slouch-Extra
#  after 2.7835312804407204 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Slouch-Extra/product-reviews/B09X6ZWK2S
# please check the fiel, 62_review_of_MONFOOT-Womens-4-Pack-Slouch-Extra.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-4-Pack-Slouch-Extra
#  after 3.5035184126250383 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Slouch-Medium/product-reviews/B0BJDKQRYX
# please check the fiel, 63_review_of_MONFOOT-Womens-4-Pack-Slouch-Medium.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-4-Pack-Slouch-Medium
#  after 1.2680264675385435 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-8-Pack-Cotton-Ankle/product-reviews/B09HS2BP1G
# please check the fiel, 64_review_of_MONFOOT-Womens-8-Pack-Cotton-Ankle.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-8-Pack-Cotton-Ankle
#  after 4.655655528858604 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-8-Pack-Cotton-Ankle/product-reviews/B09HS2PL6L
# please check the fiel, 65_review_of_MONFOOT-Womens-8-Pack-Cotton-Ankle.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-8-Pack-Cotton-Ankle
#  after 4.905744618003609 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-8-Pack-Cotton-Ankle/product-reviews/B09HRYZM33
# please check the fiel, 66_review_of_MONFOOT-Womens-8-Pack-Cotton-Ankle.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-8-Pack-Cotton-Ankle
#  after 2.3248440391111687 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Better/product-reviews/B0C9Q4V3K1
# please check the fiel, 67_review_of_MONFOOT-Womens-Athletic-Cushion-Better.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Better
#  after 4.2955585859140335 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Better/product-reviews/B0C9Q57M5V
# please check the fiel, 68_review_of_MONFOOT-Womens-Athletic-Cushion-Better.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Better
#  after 4.034778597120156 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Colored/product-reviews/B09NLJQWQM
# please check the fiel, 69_review_of_MONFOOT-Womens-Athletic-Cushioned-Colored.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Colored
#  after 1.0632221923582332 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Glitter/product-reviews/B0C9Q75MTG
# please check the fiel, 70_review_of_MONFOOT-Womens-Athletic-Cushioned-Glitter.csv
# #acc. of reviews: 6
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Glitter
#  after 1.5685880329482007 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Glitter/product-reviews/B0C9Q6LRMT
# please check the fiel, 71_review_of_MONFOOT-Womens-Athletic-Cushioned-Glitter.csv
# #acc. of reviews: 12
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Glitter
#  after 4.256393197287455 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Stripe/product-reviews/B0C9Q73141
# please check the fiel, 72_review_of_MONFOOT-Womens-Athletic-Cushioned-Stripe.csv
# #acc. of reviews: 2
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Stripe
#  after 1.366376082121077 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Stripe/product-reviews/B0C9Q5FWJ2
# please check the fiel, 73_review_of_MONFOOT-Womens-Athletic-Cushioned-Stripe.csv
# #acc. of reviews: 16
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Stripe
#  after 3.9677324478685914 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Striped/product-reviews/B09NLMKW9T
# please check the fiel, 74_review_of_MONFOOT-Womens-Athletic-Cushioned-Striped.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Striped
#  after 1.8668623532499913 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Unsorted/product-reviews/B0C9Q4M8LG
# please check the fiel, 75_review_of_MONFOOT-Womens-Athletic-Cushioned-Unsorted.csv
# #acc. of reviews: 14
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Unsorted
#  after 3.0880161897639633 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Unsorted/product-reviews/B0C9Q6KJ6H
# please check the fiel, 76_review_of_MONFOOT-Womens-Athletic-Cushioned-Unsorted.csv
# #acc. of reviews: 8
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Unsorted
#  after 5.731050284504729 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushioned-Unsorted/product-reviews/B0C9Q75MPB
# please check the fiel, 77_review_of_MONFOOT-Womens-Athletic-Cushioned-Unsorted.csv
# #acc. of reviews: 16
# get reviews of MONFOOT-Womens-Athletic-Cushioned-Unsorted
#  after 2.1464259428035977 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Glitter/product-reviews/B0C9Q541QR
# please check the fiel, 78_review_of_MONFOOT-Womens-Athletic-Cushion-Glitter.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Glitter
#  after 5.130278570368181 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Glitter/product-reviews/B0C9Q5VXDR
# please check the fiel, 79_review_of_MONFOOT-Womens-Athletic-Cushion-Glitter.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Glitter
#  after 5.707372787031555 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Glitter/product-reviews/B0C9Q6H878
# please check the fiel, 80_review_of_MONFOOT-Womens-Athletic-Cushion-Glitter.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Glitter
#  after 4.03459218298023 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Medium/product-reviews/B0C9QCDTL1
# please check the fiel, 81_review_of_MONFOOT-Womens-Athletic-Cushion-Medium.csv
# #acc. of reviews: 8
# get reviews of MONFOOT-Womens-Athletic-Cushion-Medium
#  after 5.447259062225085 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Medium/product-reviews/B0C9QCWHYD
# please check the fiel, 82_review_of_MONFOOT-Womens-Athletic-Cushion-Medium.csv
# #acc. of reviews: 16
# get reviews of MONFOOT-Womens-Athletic-Cushion-Medium
#  after 5.346500019102594 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Sorted/product-reviews/B0C9Q525ZS
# please check the fiel, 83_review_of_MONFOOT-Womens-Athletic-Cushion-Sorted.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Sorted
#  after 1.552282739348842 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Cushion-Sorted/product-reviews/B0C9Q3KGPZ
# please check the fiel, 84_review_of_MONFOOT-Womens-Athletic-Cushion-Sorted.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Cushion-Sorted
#  after 1.1924656822096331 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q6SGSG
# please check the fiel, 85_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 5.664229533196213 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q4YX5G
# please check the fiel, 86_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 2.0611620292562014 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q66VTP
# please check the fiel, 87_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 5.083877221290095 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q6Y7ZJ
# please check the fiel, 88_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 5.0062027458045 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q6SGSG
# please check the fiel, 89_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 4.488393425794778 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q5V21W
# please check the fiel, 90_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 2.935017924846166 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q4YX5G
# please check the fiel, 91_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 1.7266926964532716 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q7PQPC
# please check the fiel, 92_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 2.4287200187012132 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q6L3SX
# please check the fiel, 93_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 4.136120114221685 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushion/product-reviews/B0C9Q3QP4H
# please check the fiel, 94_review_of_MONFOOT-Womens-Athletic-Skate-Cushion.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushion
#  after 5.925578562524924 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK284L5
# please check the fiel, 95_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 3.5074164159024863 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1YK5R
# please check the fiel, 96_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 5.6446597484809535 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK252N1
# please check the fiel, 97_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 4.306935412175405 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK22NQX
# please check the fiel, 98_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 3.894192857310893 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1CR76
# please check the fiel, 99_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 3.1639195748249684 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK23HD2
# please check the fiel, 100_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 3.2465753867585136 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1WJG9
# please check the fiel, 101_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 2.6260681527942578 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRJZNF2Q
# please check the fiel, 102_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 2.7643263260068123 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1HMP2
# please check the fiel, 103_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 1.9601574615862873 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1FC6V
# please check the fiel, 104_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 4.5864743917595945 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK29XTQ
# please check the fiel, 105_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 5.831207427180983 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1D33K
# please check the fiel, 106_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 5.717039284496691 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK1GJJ9
# please check the fiel, 107_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 1.305161414561908 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Athletic-Skate-Cushioned/product-reviews/B0BRK284L5
# please check the fiel, 108_review_of_MONFOOT-Womens-Athletic-Skate-Cushioned.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-Athletic-Skate-Cushioned
#  after 4.348553732054984 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Cotton-Lightweight-Quarter/product-reviews/B08BLBT6XV
# please check the fiel, 109_review_of_MONFOOT-Womens-Cotton-Lightweight-Quarter.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-Cotton-Lightweight-Quarter
#  after 5.205727222786283 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Cotton-Lightweight-Quarter/product-reviews/B08BL99K7P
# please check the fiel, 110_review_of_MONFOOT-Womens-Cotton-Lightweight-Quarter.csv
# #acc. of reviews: 90
# get reviews of MONFOOT-Womens-Cotton-Lightweight-Quarter
#  after 4.894720702985716 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Cotton-Lightweight-Quarter/product-reviews/B08BLBT6XV
# please check the fiel, 111_review_of_MONFOOT-Womens-Cotton-Lightweight-Quarter.csv
# #acc. of reviews: 110
# get reviews of MONFOOT-Womens-Cotton-Lightweight-Quarter
#  after 4.719544827857171 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Cotton-Lightweight-Quarter/product-reviews/B08BLD489K
# please check the fiel, 112_review_of_MONFOOT-Womens-Cotton-Lightweight-Quarter.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-Cotton-Lightweight-Quarter
#  after 1.4989863487704298 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Glitter-Comfortable-Quarter/product-reviews/B0C9Q4BZ6W
# please check the fiel, 113_review_of_MONFOOT-Womens-Glitter-Comfortable-Quarter.csv
# #acc. of reviews: 80
# get reviews of MONFOOT-Womens-Glitter-Comfortable-Quarter
#  after 2.280602923275491 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Glitter-Comfortable-Quarter/product-reviews/B0C9Q7C5JL
# please check the fiel, 114_review_of_MONFOOT-Womens-Glitter-Comfortable-Quarter.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-Glitter-Comfortable-Quarter
#  after 3.2577961546814747 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Glitter-Comfortable-Quarter/product-reviews/B0C9Q5Y79S
# please check the fiel, 115_review_of_MONFOOT-Womens-Glitter-Comfortable-Quarter.csv
# #acc. of reviews: 60
# get reviews of MONFOOT-Womens-Glitter-Comfortable-Quarter
#  after 3.41735841691549 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip/product-reviews/B09NCTJ926
# please check the fiel, 116_review_of_MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip
#  after 4.279056439784711 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip/product-reviews/B09NCS9T23
# please check the fiel, 117_review_of_MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-5-Pairs-Cushioned-No-Show-Non-slip
#  after 1.5834418146038427 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CK9XHFN
# please check the fiel, 118_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 2.2131351447206695 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CKBYQ6H
# please check the fiel, 119_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 3.398649940664267 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton/product-reviews/B08CK6GML3
# please check the fiel, 120_review_of_MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Eco-friendly-Cushioned-Wholesale-Packs_cotton
#  after 1.9035975181197042 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B08N64TBK1
# please check the fiel, 121_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 5.226990098618334 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Pairs-Cushion-Non-Slip-Socks/product-reviews/B093ZK6LVD
# please check the fiel, 122_review_of_MONFOOT-Pairs-Cushion-Non-Slip-Socks.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Pairs-Cushion-Non-Slip-Socks
#  after 2.1219378517648075 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Women-Pairs-Moisturizing-Slipper/product-reviews/B0986XZS4M
# please check the fiel, 123_review_of_MONFOOT-Women-Pairs-Moisturizing-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Women-Pairs-Moisturizing-Slipper
#  after 1.9700614366695355 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Women-Pairs-Moisturizing-Slipper/product-reviews/B09871TFJC
# please check the fiel, 124_review_of_MONFOOT-Women-Pairs-Moisturizing-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Women-Pairs-Moisturizing-Slipper
#  after 2.798550626997126 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Women-Pairs-Moisturizing-Slipper/product-reviews/B0986XZS4M
# please check the fiel, 125_review_of_MONFOOT-Women-Pairs-Moisturizing-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Women-Pairs-Moisturizing-Slipper
#  after 1.8482980830939724 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Women-Pairs-Moisturizing-Slipper/product-reviews/B0986ZK6YH
# please check the fiel, 126_review_of_MONFOOT-Women-Pairs-Moisturizing-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Women-Pairs-Moisturizing-Slipper
#  after 1.7866079669000037 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-3-Pack-Vintage-Socks/product-reviews/B09X6ZQRKV
# please check the fiel, 127_review_of_MONFOOT-Womens-3-Pack-Vintage-Socks.csv
# #acc. of reviews: 70
# get reviews of MONFOOT-Womens-3-Pack-Vintage-Socks
#  after 2.0762776450569813 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-3-Pack-Vintage-Socks/product-reviews/B09X6Z9ZGJ
# please check the fiel, 128_review_of_MONFOOT-Womens-3-Pack-Vintage-Socks.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-3-Pack-Vintage-Socks
#  after 4.551617359250195 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-3-Pack-Vintage-Socks/product-reviews/B09X6Y9VXN
# please check the fiel, 129_review_of_MONFOOT-Womens-3-Pack-Vintage-Socks.csv
# #acc. of reviews: 80
# get reviews of MONFOOT-Womens-3-Pack-Vintage-Socks
#  after 4.513057362673953 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Cushioned-Multicolor/product-reviews/B09HS3PW93
# please check the fiel, 130_review_of_MONFOOT-Womens-4-Pack-Cushioned-Multicolor.csv
# #acc. of reviews: 50
# get reviews of MONFOOT-Womens-4-Pack-Cushioned-Multicolor
#  after 1.8599591505981548 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-4-Pack-Slouch-Extra/product-reviews/B09X6ZWK2S
# please check the fiel, 131_review_of_MONFOOT-Womens-4-Pack-Slouch-Extra.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-4-Pack-Slouch-Extra
#  after 2.3063168662195923 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Cotton-Cushioned-Ankle/product-reviews/B09X16GB2K
# please check the fiel, 132_review_of_MONFOOT-Womens-Cotton-Cushioned-Ankle.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Womens-Cotton-Cushioned-Ankle
#  after 4.975267960981771 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Mens-Vintage-Socks/product-reviews/B0C9QCPWXJ
# please check the fiel, 133_review_of_MONFOOT-Womens-Mens-Vintage-Socks.csv
# #acc. of reviews: 20
# get reviews of MONFOOT-Womens-Mens-Vintage-Socks
#  after 4.873776446776212 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Slouch-Cotton-Tie-Dye/product-reviews/B0C9Q8V4ST
# please check the fiel, 134_review_of_MONFOOT-Womens-Slouch-Cotton-Tie-Dye.csv
# #acc. of reviews: 40
# get reviews of MONFOOT-Womens-Slouch-Cotton-Tie-Dye
#  after 3.5655449551602643 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Slouch-Extra-Polytam/product-reviews/B0C9QBFDF1
# please check the fiel, 135_review_of_MONFOOT-Womens-Slouch-Extra-Polytam.csv
# #acc. of reviews: 0
# get reviews of MONFOOT-Womens-Slouch-Extra-Polytam
#  after 3.2838962265017115 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Super-Fuzzy-Slipper/product-reviews/B0C9QC35SP
# please check the fiel, 136_review_of_MONFOOT-Womens-Super-Fuzzy-Slipper.csv
# #acc. of reviews: 30
# get reviews of MONFOOT-Womens-Super-Fuzzy-Slipper
#  after 1.5001723954312647 seconds, we try again
# [review] https://www.amazon.com/MONFOOT-Womens-Vintage-Socks-Natural/product-reviews/B0C9QD5GHP
# please check the fiel, 137_review_of_MONFOOT-Womens-Vintage-Socks-Natural.csv
# #acc. of reviews: 10
# get reviews of MONFOOT-Womens-Vintage-Socks-Natural
#  after 4.866115860194908 seconds, we try again
# Total number of reviews: 6576
# Crawling reviews from amazon is completed !!!
